# %% [markdown]
# # Daten

# %%
import pandas as pd

# %%
# Methode 1: Spezifizieren Sie den vollständigen Pfad zur Datei

# %%
# Windows
# stats= pd.read_csv('C:\\Users\\UserName\\Desktop\\...')

# Unix
stats= pd.read_csv('../Data/DemographicData.csv') # erhalte über den "pwd" command den vollständigen File Pfad

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# 11                          Burundi          BDI      44.151         1.30000
# 12                          Belgium          BEL      11.200        82.17020
# 13                            Benin          BEN      36.440         4.90000
# 14                     Burkina Faso          BFA      40.551         9.10000
# 15                       Bangladesh          BGD      20.142         6.63000
# 16                         Bulgaria          BGR       9.200        53.06150
# 17                          Bahrain          BHR      15.040        90.00004
# 18                     Bahamas, The          BHS      15.339        72.00000
# 19           Bosnia and Herzegovina          BIH       9.062        57.79000
# 20                          Belarus          BLR      12.500        54.17000
# 21                           Belize          BLZ      23.092        33.60000
# 22                          Bermuda          BMU      10.400        95.30000
# 23                          Bolivia          BOL      24.236        36.94000
# 24                           Brazil          BRA      14.931        51.04000
# 25                         Barbados          BRB      12.188        73.00000
# 26                Brunei Darussalam          BRN      16.405        64.50000
# 27                           Bhutan          BTN      18.134        29.90000
# 28                         Botswana          BWA      25.267        15.00000
# 29         Central African Republic          CAF      34.076         3.50000
# ..                              ...          ...         ...             ...
# 165                      Seychelles          SYC      18.600        50.40000
# 166            Syrian Arab Republic          SYR      24.043        26.20000
# 167                            Chad          TCD      45.745         2.30000
# 168                            Togo          TGO      36.080         4.50000
# 169                        Thailand          THA      11.041        28.94000
# 170                      Tajikistan          TJK      30.792        16.00000
# 171                    Turkmenistan          TKM      21.322         9.60000
# 172                     Timor-Leste          TLS      35.755         1.10000
# 173                           Tonga          TON      25.409        35.00000
# 174             Trinidad and Tobago          TTO      14.590        63.80000
# 175                         Tunisia          TUN      19.800        43.80000
# 176                          Turkey          TUR      16.836        46.25000
# 177                        Tanzania          TZA      39.518         4.40000
# 178                          Uganda          UGA      43.474        16.20000
# 179                         Ukraine          UKR      11.100        41.00000
# 180                         Uruguay          URY      14.374        57.69000
# 181                   United States          USA      12.500        84.20000
# 182                      Uzbekistan          UZB      22.500        38.20000
# 183  St. Vincent and the Grenadines          VCT      16.306        52.00000
# 184                   Venezuela, RB          VEN      19.842        54.90000
# 185           Virgin Islands (U.S.)          VIR      10.700        45.30000
# 186                         Vietnam          VNM      15.537        43.90000
# 187                         Vanuatu          VUT      26.739        11.30000
# 188              West Bank and Gaza          PSE      30.394        46.60000
# 189                           Samoa          WSM      26.172        15.30000
# 190                     Yemen, Rep.          YEM      32.947        20.00000
# 191                    South Africa          ZAF      20.850        46.50000
# 192                Congo, Dem. Rep.          COD      42.394         2.20000
# 193                          Zambia          ZMB      40.471        15.40000
# 194                        Zimbabwe          ZWE      35.715        18.50000
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
# Methode 2: Ändere das Arbeitsverzeichnis zu den Daten

# %%
import os

# %%
print(os.getcwd())
# Out:
# /home/ubuntu/workspace/5 - Visualization I

# %%
# Windows: 
# os.chdir('C:\\Users\\User')

# Mac
# os.chdir('/home/ubuntu/Desktop')

# %% [markdown]
# ### Grundlegende Operationen mit data.frame

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[['Country Name', 'Birth rate', 'Internet users']]
# Out:
#                        Country Name  Birth rate  Internet users
# 0                             Aruba      10.244        78.90000
# 1                       Afghanistan      35.253         5.90000
# 2                            Angola      45.985        19.10000
# 3                           Albania      12.877        57.20000
# 4              United Arab Emirates      11.044        88.00000
# 5                         Argentina      17.716        59.90000
# 6                           Armenia      13.308        41.90000
# 7               Antigua and Barbuda      16.447        63.40000
# 8                         Australia      13.200        83.00000
# 9                           Austria       9.400        80.61880
# 10                       Azerbaijan      18.300        58.70000
# 11                          Burundi      44.151         1.30000
# 12                          Belgium      11.200        82.17020
# 13                            Benin      36.440         4.90000
# 14                     Burkina Faso      40.551         9.10000
# 15                       Bangladesh      20.142         6.63000
# 16                         Bulgaria       9.200        53.06150
# 17                          Bahrain      15.040        90.00004
# 18                     Bahamas, The      15.339        72.00000
# 19           Bosnia and Herzegovina       9.062        57.79000
# 20                          Belarus      12.500        54.17000
# 21                           Belize      23.092        33.60000
# 22                          Bermuda      10.400        95.30000
# 23                          Bolivia      24.236        36.94000
# 24                           Brazil      14.931        51.04000
# 25                         Barbados      12.188        73.00000
# 26                Brunei Darussalam      16.405        64.50000
# 27                           Bhutan      18.134        29.90000
# 28                         Botswana      25.267        15.00000
# 29         Central African Republic      34.076         3.50000
# ..                              ...         ...             ...
# 165                      Seychelles      18.600        50.40000
# 166            Syrian Arab Republic      24.043        26.20000
# 167                            Chad      45.745         2.30000
# 168                            Togo      36.080         4.50000
# 169                        Thailand      11.041        28.94000
# 170                      Tajikistan      30.792        16.00000
# 171                    Turkmenistan      21.322         9.60000
# 172                     Timor-Leste      35.755         1.10000
# 173                           Tonga      25.409        35.00000
# 174             Trinidad and Tobago      14.590        63.80000
# 175                         Tunisia      19.800        43.80000
# 176                          Turkey      16.836        46.25000
# 177                        Tanzania      39.518         4.40000
# 178                          Uganda      43.474        16.20000
# 179                         Ukraine      11.100        41.00000
# 180                         Uruguay      14.374        57.69000
# 181                   United States      12.500        84.20000
# 182                      Uzbekistan      22.500        38.20000
# 183  St. Vincent and the Grenadines      16.306        52.00000
# 184                   Venezuela, RB      19.842        54.90000
# 185           Virgin Islands (U.S.)      10.700        45.30000
# 186                         Vietnam      15.537        43.90000
# 187                         Vanuatu      26.739        11.30000
# 188              West Bank and Gaza      30.394        46.60000
# 189                           Samoa      26.172        15.30000
# 190                     Yemen, Rep.      32.947        20.00000
# 191                    South Africa      20.850        46.50000
# 192                Congo, Dem. Rep.      42.394         2.20000
# 193                          Zambia      40.471        15.40000
# 194                        Zimbabwe      35.715        18.50000
#
# [195 rows x 3 columns]

# %%
stats[['Country Name', 'Birth rate', 'Internet users']][4:8]
# Out:
#            Country Name  Birth rate  Internet users
# 4  United Arab Emirates      11.044            88.0
# 5             Argentina      17.716            59.9
# 6               Armenia      13.308            41.9
# 7   Antigua and Barbuda      16.447            63.4

# %% [markdown]
# ## Mathematische Operationen

# %%
result = stats['Birth rate'] * stats['Internet users']

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %% [markdown]
# Fügt eine Spalte zu df hinzu

# %%
stats['MyCalc'] = stats['Birth rate'] * stats['Internet users']

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
#comparison to R
stats['xyz'] = [1,2,3,4,5] # Python does not recycle vectors! (as instead of R)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5bbe8968bb86> in <module>
#       1 #comparison to R
# ----> 2 stats['xyz'] = [1,2,3,4,5] # Python does not recycle vectors! (as instead of R)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
#    3392             if not isinstance(value, (np.ndarray, Index)):
#    3393                 if isinstance(value, list) and len(value) > 0:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3999
#    4000     if len(data) != len(index):
# -> 4001         raise ValueError('Length of values does not match length of ' 'index')
#    4002
#    4003     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
# Entferne eine Spalte
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats = stats.drop(['MyCalc'], 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-6b61991b3d90> in <module>
# ----> 1 stats = stats.drop(['MyCalc'], 1)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['MyCalc'] not found in axis"

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# 11                          Burundi          BDI      44.151         1.30000
# 12                          Belgium          BEL      11.200        82.17020
# 13                            Benin          BEN      36.440         4.90000
# 14                     Burkina Faso          BFA      40.551         9.10000
# 15                       Bangladesh          BGD      20.142         6.63000
# 16                         Bulgaria          BGR       9.200        53.06150
# 17                          Bahrain          BHR      15.040        90.00004
# 18                     Bahamas, The          BHS      15.339        72.00000
# 19           Bosnia and Herzegovina          BIH       9.062        57.79000
# 20                          Belarus          BLR      12.500        54.17000
# 21                           Belize          BLZ      23.092        33.60000
# 22                          Bermuda          BMU      10.400        95.30000
# 23                          Bolivia          BOL      24.236        36.94000
# 24                           Brazil          BRA      14.931        51.04000
# 25                         Barbados          BRB      12.188        73.00000
# 26                Brunei Darussalam          BRN      16.405        64.50000
# 27                           Bhutan          BTN      18.134        29.90000
# 28                         Botswana          BWA      25.267        15.00000
# 29         Central African Republic          CAF      34.076         3.50000
# ..                              ...          ...         ...             ...
# 165                      Seychelles          SYC      18.600        50.40000
# 166            Syrian Arab Republic          SYR      24.043        26.20000
# 167                            Chad          TCD      45.745         2.30000
# 168                            Togo          TGO      36.080         4.50000
# 169                        Thailand          THA      11.041        28.94000
# 170                      Tajikistan          TJK      30.792        16.00000
# 171                    Turkmenistan          TKM      21.322         9.60000
# 172                     Timor-Leste          TLS      35.755         1.10000
# 173                           Tonga          TON      25.409        35.00000
# 174             Trinidad and Tobago          TTO      14.590        63.80000
# 175                         Tunisia          TUN      19.800        43.80000
# 176                          Turkey          TUR      16.836        46.25000
# 177                        Tanzania          TZA      39.518         4.40000
# 178                          Uganda          UGA      43.474        16.20000
# 179                         Ukraine          UKR      11.100        41.00000
# 180                         Uruguay          URY      14.374        57.69000
# 181                   United States          USA      12.500        84.20000
# 182                      Uzbekistan          UZB      22.500        38.20000
# 183  St. Vincent and the Grenadines          VCT      16.306        52.00000
# 184                   Venezuela, RB          VEN      19.842        54.90000
# 185           Virgin Islands (U.S.)          VIR      10.700        45.30000
# 186                         Vietnam          VNM      15.537        43.90000
# 187                         Vanuatu          VUT      26.739        11.30000
# 188              West Bank and Gaza          PSE      30.394        46.60000
# 189                           Samoa          WSM      26.172        15.30000
# 190                     Yemen, Rep.          YEM      32.947        20.00000
# 191                    South Africa          ZAF      20.850        46.50000
# 192                Congo, Dem. Rep.          COD      42.394         2.20000
# 193                          Zambia          ZMB      40.471        15.40000
# 194                        Zimbabwe          ZWE      35.715        18.50000
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# 15   Lower middle income
# 16   Upper middle income
# 17           High income
# 18           High income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 22           High income
# 23   Lower middle income
# 24   Upper middle income
# 25           High income
# 26           High income
# 27   Lower middle income
# 28   Upper middle income
# 29            Low income
# ..                   ...
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %% [markdown]
# ## Filtering df

# %%
# Filtering is about rows

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats['Internet users'] < 2 # Gibt uns alle Internetnutzer an, deren Wert kleiner als 2 ist
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: Internet users, Length: 195, dtype: bool

# %%
Filter = stats['Internet users'] < 2

# %%
stats[Filter] # benutze Filter auf dem stats-Objekt, selbe wie in R !!!
# Out:
#      Country Name Country Code  Birth rate  Internet users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income Group
# 11            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 117  Lower middle income
# 127           Low income
# 154           Low income
# 156           Low income
# 172  Lower middle income

# %%
stats['Birth rate'] > 40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167     True
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178     True
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: Birth rate, Length: 195, dtype: bool

# %%
Filter2 = stats['Birth rate'] > 40 #mehr als 40 Kinder werden pro 1000 Kinder pro Jahr geboren

# %%
stats[Filter2]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# 128  Lower middle income
# 156           Low income
# 167           Low income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
# mehrere Filter kombinieren
stats[stats['Birth rate'] > 40 and stats['Internet users'] < 2] # R-Style...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-a47c748f6acb> in <module>
#       1 # mehrere Filter kombinieren
# ----> 2 stats[stats['Birth rate'] > 40 and stats['Internet users'] < 2] # R-Style...
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats['Birth rate'] > 40 and stats['Internet users'] < 2 ## Error is here!!!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-bf61420bbf8a> in <module>
# ----> 1 stats['Birth rate'] > 40 and stats['Internet users'] < 2 ## Error is here!!!
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats[Filter & Filter2] # Verwende bitweise Operatoren
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group
# 11       Burundi          BDI      44.151             1.3   Low income
# 127        Niger          NER      49.661             1.7   Low income
# 156      Somalia          SOM      43.891             1.5   Low income

# %%
stats[(stats['Birth rate'] > 40) & (stats['Internet users'] < 2)]
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group
# 11       Burundi          BDI      44.151             1.3   Low income
# 127        Niger          NER      49.661             1.7   Low income
# 156      Somalia          SOM      43.891             1.5   Low income

# %%
stats[(stats['Income Group'] == 'High Income')] ## Für boolesche Operatoren muss '==' verwendet werden
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Birth rate, Internet users, Income Group]
# Index: []

# %%
stats['Income Group'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %% [markdown]
# ## !Challenge!

# %% [markdown]
# Filtere alles über Österreich

# %%
FilterM = stats['Country Name'] == 'Austria'
stats[FilterM]
# Out:
#   Country Name Country Code  Birth rate  Internet users Income Group
# 9      Austria          AUT         9.4         80.6188  High income

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ## .at() vs. .iat()

# %%
#.at() # für Beschriftungen wichtig: Gerade Ganzzahlen werden als Beschriftungen behandelt
#.iat() # für den Ort bei einer Ganzzahl

# %%
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.iat[0,0]
# Out:
# 'Aruba'

# %%
stats.at[2, 'Birth rate']
# Out:
# 45.985

# %%
stats.at[3, 'Country Name']
# Out:
# 'Albania'

# %%
# Warum brauchen wir .at

# %%
sub10 = stats[::10]

# %%
sub10
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 0          Aruba          ABW      10.244       78.900000          High income
# 10    Azerbaijan          AZE      18.300       58.700000  Upper middle income
# 20       Belarus          BLR      12.500       54.170000  Upper middle income
# 30        Canada          CAN      10.900       85.800000          High income
# 40    Costa Rica          CRI      15.022       45.960000  Upper middle income
# 50       Ecuador          ECU      21.070       40.353684  Upper middle income
# 60         Gabon          GAB      30.555        9.200000  Upper middle income
# 70     Greenland          GRL      14.500       65.800000          High income
# 80         India          IND      20.291       15.100000  Lower middle income
# 90    Kazakhstan          KAZ      22.730       54.000000  Upper middle income
# 100        Libya          LBY      21.425       16.500000  Upper middle income
# 110      Moldova          MDA      12.141       45.000000  Lower middle income
# 120   Mozambique          MOZ      39.705        5.400000           Low income
# 130  Netherlands          NLD      10.200       93.956400          High income
# 140       Poland          POL       9.600       62.849200          High income
# 150        Sudan          SDN      33.477       22.700000  Lower middle income
# 160     Suriname          SUR      18.455       37.400000  Upper middle income
# 170   Tajikistan          TJK      30.792       16.000000  Lower middle income
# 180      Uruguay          URY      14.374       57.690000          High income
# 190  Yemen, Rep.          YEM      32.947       20.000000  Lower middle income

# %%
sub10.iat[10,0] # zählt die Zeilen und erhält den Index
# Out:
# 'Libya'

# %%
sub10.at[10,'Country Name'] # sucht nach Labels und NICHT nach Index
# Out:
# 'Azerbaijan'

# %% [markdown]
# ## Einführung in die Seaborn-Bibliothek

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
#Verteilung
vis1 = sns.distplot(stats['Internet users'], bins=30)

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# # Boxplots

# %%
vis2 = sns.boxplot(data=stats, x="Income Group", y="Birth rate")

# %% [markdown]
# ---

# %% [markdown]
# # Scatterplot

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
vis3 = sns.lmplot(data=stats, x='Internet users' , y='Birth rate', fit_reg=False) # add fit_reg verursacht eine nicht lineare Beziehung

# %%
vis1 = sns.distplot(stats['Birth rate'], bins=30)

# %%
# Farben zum Diagramm hinzufügen
vis3 = sns.lmplot(data=stats, x='Internet users' , y='Birth rate', fit_reg=False, hue='Income Group')

# %%
vis3 = sns.lmplot(data=stats, x='Internet users' , y='Birth rate', fit_reg=False, hue='Income Group', size=10, aspect=0.5)

# %% [markdown]
# ---

# %% [markdown]
# ### Keyword Arguments in Python

# %%
vis3 = sns.lmplot(data=stats, x='Internet users' , y='Birth rate', fit_reg=False, hue='Income Group', size=8, scatter_kws={"s":200}) # s is a dictrionary and comes from mathplotlib
